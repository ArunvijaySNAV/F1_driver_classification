# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.image import imread

print(np.__version__)
print(cv2.__version__)
# Out:
# 2.5.1
# 5.0.0

# %%
 def if_image_eyes(image_path):
    if image_path.split('.')[1] == 'jpg':

        original_img = cv2.imread(image_path)

        # convertion of the original image into the back and white image
        bw_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2GRAY)

        # image cascading
        face_cascade = cv2.CascadeClassifier(
            '/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/opencv/haarcascades/haarcascade_frontalface_default.xml')
        eye_cascade = cv2.CascadeClassifier(
            '/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/opencv/haarcascades/haarcascade_eye.xml')

        # used cascade and detecting face
        face_images = face_cascade.detectMultiScale(bw_img)
        for (x, y, w, h) in face_images:
            rec_pic = cv2.rectangle(original_img, (x, y), (x + h, y + w), (255, 0, 0), 2)

            gray_roi = bw_img[y:y + h, x:x + w]
            face_roi = rec_pic[y:y + h, x:x + w]

            eyes = eye_cascade.detectMultiScale(gray_roi)

            if len(eyes) == 2:
                for (ex, ey, ew, eh) in eyes:
                    pass
                    #cv2.rectangle(face_roi, (ex, ey), (ex + eh, ey + ew), (0, 255, 0), 2)

                plt.figure()
                plt.imshow(face_roi)
                plt.show()

            else:
                return None

# %%
lst_drivers = ['/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/lando norris/Italian Grand Prix_ Lando Norris on pole as part of McLaren one-two, Max Verstappen only seventh - BBC Sport.jpg',
               '/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/lando norris/Lando Norris - Wikipedia-001.jpg',
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/lando norris/GRANDPRIX247 _ Lando Norris_ How He Became McLaren's Star Driver.jpg",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/lewis hamilton/David Coulthard looks at the key issues surrounding Lewis Hamilton's next deal _ The Independent.jpg",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/lewis hamilton/Go Bright or Go Home_ Lewis Hamilton in ZEGNA - Time International.jpg",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/lewis hamilton/Happy Birthday to Sir Lewis Hamilton, the most successful F1 driver of all time turns 41 today! _ r_formula1.jpg",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/lewis hamilton/Lewis Hamilton, Ferrari, the effect of ageing in an athlete and the quest for a 'magic solution' - BBC Sport.jpg",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/lewis hamilton/Lewis Hamilton - Dyslexia Help.png",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/charles leclerc/A Moment in Motion_ Charles Leclerc's Wedding Drive in a Testa Rossa - Petrolicious.jpg",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/charles leclerc/Buy Charles Leclerc F1 2024 - A3 or A4 Poster Online in India - Etsy.jpg",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/charles leclerc/Charles Leclerc, happy to be back on podium at US Grand Prix.jpg",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/charles leclerc/Charles Leclerc 'miles ahead' in Monaco - Max Verstappen - BBC Sport.jpg",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/charles leclerc/Charles Leclerc_ _Anything that I didn't win, I don't remember_ _ GQ India.jpg",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/max verstappen/Autosport] Max Verstappen talking through his 'overtake of the month' on Lewis Hamilton _ r_formula1.jpg",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/max verstappen/Azerbaijan Grand Prix_ Max Verstappen, Red Bull seek to bounce back at Formula 1's Baku leg _ South China Morning Post.jpg",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/max verstappen/F1 qualifying results_ Max Verstappen thunders to pole at the Italian Grand Prix _ SB Nation.jpg",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/max verstappen/Max Verstappen _ Biography, F1 Championships, Age, Net Worth, Father, & Facts _ Britannica.jpg",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/max verstappen/Max Verstappen _ Biography, F1 Championships, Age, Net Worth, Father, & Facts _ Britannica.jpg",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/alonso/F1_ Fernando Alonso Still Has His Eye on the Prize - The New York Times.jpg",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/alonso/Fernando Alonso.jpg",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/alonso/Fernando Alonso - Aston Martin F1 Team.jpg",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/alonso/Fernando Alonso - F1 Driver for Aston Martin-001.jpg",
               "/Users/snarunvijay/Documents/Machine_Learning/ImageClassification/model/dataset/alonso/Fernando Alonso - F1® Manager 2024.jpg"
]

# %%
for drivers in lst_drivers:
    if_image_eyes(drivers)
